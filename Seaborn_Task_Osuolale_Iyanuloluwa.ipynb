# %% [markdown]
# <a href="https://colab.research.google.com/github/dmarinere/10academysolution/blob/master/Seaborn_Task_Osuolale_Iyanuloluwa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Seaborn Tasks

# %% [markdown]
# Osuolale Iyanuloluwa
# dmarinere@gmail.com

# %% [markdown]
# ## Tasks 1

# %% [markdown]
# Import the pandas_tasks.csv

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set();

# %%
data = pd.read_csv("/content/drive/My Drive/Thursday-Week0/pandas_tasks.csv")

# %% [markdown]
# #### Question 1. Make a scatter plot of the Longitude and Latitude columns

# %%
sns.scatterplot(data=data, x='Latitude', y='Longitude');

# %% [markdown]
# #### Question 2. Make a scatter plot of the Longitude and Latitude columns. This time, plot with 'hue' = Q2 and compare it over Q3

# %%
sns.scatterplot(x='Latitude', y='Longitude', data=data, hue='Q2');

# %% [markdown]
# #### Question 3. Make a boxplot of Longiture and Q2

# %%
sns.boxplot(x='Q2', y='Longitude', data=data);

# %% [markdown]
# #### Question 4. Make a count plot of all the categorical variables in the dataset.

# %% [markdown]
# Here are my Count plot for all the categorical variables

# %%
sns.countplot(data=data, x='Q2', palette='husl');

# %%
sns.countplot(data=data, x='Q3', palette='husl');

# %%
sns.countplot(data=data, x='Q4', palette='husl');

# %%
sns.countplot(data=data, x='Q5', palette='Set1');

# %%
sns.countplot(data=data, x='Q6', palette='husl');

# %%
sns.countplot(data=data, x='Q7', palette='husl');

# %%
sns.countplot(data=data, x='Q8_1', palette='Set1');

# %%
sns.countplot(data=data, x='Q8_2', palette='Set2');

# %%
sns.countplot(data=data, x='Q8_3', palette='Set1');

# %%
sns.countplot(data=data, x='Q8_4', palette='Set1');

# %%
sns.countplot(data=data, x='Q8_5', palette='Set1');

# %%
sns.countplot(data=data, x='Q8_6', palette='Set1');

# %%
sns.countplot(data=data, x='Q8_7', palette='Set1')

# %%
sns.countplot(data=data, x='Q8_8', palette='Set1');

# %%
sns.countplot(data=data, x='Q8_8', palette='Set1');

# %%
sns.countplot(data=data, x='Q8_10', palette='Set1');

# %%
sns.countplot(data=data, x='Q8_11', palette='Set1');

# %%
sns.countplot(data=data, x='Q9', palette='Set1');

# %%
sns.countplot(data=data, x='Q10', palette='Set1');

# %%
sns.countplot(data=data, x='Q10', palette='Set1');

# %%
sns.countplot(data=data, x='Q11', palette='Set1');

# %%
sns.countplot(data=data, x='Q12', palette='Set1');

# %%
sns.countplot(data=data, x='Q13', palette='Set1');

# %%
sns.countplot(data=data, x='Q14', palette='Set1');

# %%
sns.countplot(data=data, x='Q15', palette='Set2');

# %%
sns.countplot(data=data, x='Q16', palette='Set2');

# %%
sns.countplot(data=data, x='Q17', palette='Set3');

# %%
sns.countplot(data=data, x='Q18', palette='Set1');

# %%
sns.countplot(data=data, x='Q19', palette='Set1');

# %%
sns.countplot(data=data, x='mobile_money', palette='Set1')

# %%
sns.countplot(data=data, x='savings', palette='Set1')

# %%
sns.countplot(data=data, x='borrowing', palette='Set1')

# %%
sns.countplot(data=data, x='insurance', palette='Set1')

# %%
sns.countplot(data=data, x='mobile_money_classification', palette='Set1')
